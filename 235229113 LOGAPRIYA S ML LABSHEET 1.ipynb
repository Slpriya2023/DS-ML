# %% [markdown]
# ## 1. Read and display the files of tabular data

# %% [markdown]
# ### Printing properties like Size,shape,dimensions

# %%
import pandas as pd

# %%
df=pd.read_csv('Iris.csv')

# %%
print(df.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.size
# Out:
# 900

# %%
df.ndim
# Out:
# 2

# %%
df.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.size
# Out:
# 900

# %%
df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]>

# %%
df.plot('Species','SepalLengthCm')
# Out:
# <Axes: xlabel='Species'>

# %%
df.plot()
# Out:
# <Axes: >

# %%
#bar graph

# %%
# importing pandas module
import pandas as pd
 
# reading csv file
data = pd.read_csv("iris.csv")
 
# dataframe.ndim
df_ndim = data.ndim
 
# series.ndim
series_ndim = data["SepalLengthCm"].ndim
 
# printing ndim
print("ndim of dataframe = {}\nndim of series ={}".
      format(df_ndim, series_ndim))
# Out:
# ndim of dataframe = 2
# ndim of series =1

# %%
import seaborn as a
g=a.pairplot(df,kind="reg")
# Out:
# C:\Users\slogp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x="SepalWidthCm",y="PetalLengthCm")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalLengthCm'>

# %%
from matplotlib import pyplot as plt
teams = ['Argentina', 'Canada', 'France', 'Morocco', ' Portugal']
won = [74, 43, 38, 51, 50]
fig = plt.figure(figsize =(8,8))
plt.pie(won,labels = teams)
# Out:
# ([<matplotlib.patches.Wedge at 0x204cfec0a90>,
#   <matplotlib.patches.Wedge at 0x204cfec1490>,
#   <matplotlib.patches.Wedge at 0x204cfec2450>,
#   <matplotlib.patches.Wedge at 0x204cfec3510>,
#   <matplotlib.patches.Wedge at 0x204cfed44d0>],
#  [Text(0.6767547496386895, 0.867181070389267, 'Argentina'),
#   Text(-0.7682138743498701, 0.7873039078122006, 'Canada'),
#   Text(-1.0788638084435536, -0.2145993542177412, 'France'),
#   Text(-0.306371658323559, -1.0564735713571223, 'Morocco'),
#   Text(0.8993432944667421, -0.6333890105596298, ' Portugal')])

# %%
# # "TSV" — tab-separated values (.tsv)

# %%
import pandas as pd 
df = pd.read_csv('FIFAtsv.txt',sep = '\t')
print(df)
# Out:
#     Id,SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 0                        1,5.1,3.5,1.4,0.2,Iris-setosa
# 1                        2,4.9,3.0,1.4,0.2,Iris-setosa
# 2                        3,4.7,3.2,1.3,0.2,Iris-setosa
# 3                        4,4.6,3.1,1.5,0.2,Iris-setosa
# 4                        5,5.0,3.6,1.4,0.2,Iris-setosa
# ..                                                 ...
# 145                 146,6.7,3.0,5.2,2.3,Iris-virginica
# 146                 147,6.3,2.5,5.0,1.9,Iris-virginica
# 147                 148,6.5,3.0,5.2,2.0,Iris-virginica
# 148                 149,6.2,3.4,5.4,2.3,Iris-virginica
# 149                 150,5.9,3.0,5.1,1.8,Iris-virginica
#
# [150 rows x 1 columns]

# %%
# # “ARFF” - Attribute-Relation File Format (.arff)

# %%
import pandas as pd
file=pd.read_csv('FIFA dataset.arff',sep='\t')
file.head()
# Out:
#   Id,SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 0                      1,5.1,3.5,1.4,0.2,Iris-setosa
# 1                      2,4.9,3.0,1.4,0.2,Iris-setosa
# 2                      3,4.7,3.2,1.3,0.2,Iris-setosa
# 3                      4,4.6,3.1,1.5,0.2,Iris-setosa
# 4                      5,5.0,3.6,1.4,0.2,Iris-setosa

# %%
# # 2. Read and display the spreadsheet files

# %%
# # "XLS" — Excel spreadsheet (.xls)

# %%
import pandas as pd
file=("WorldCup2022_ScoreChart_no_macro_20221218.xls")
a=pd.read_excel(file)
a
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 3
#       1 import pandas as pd
#       2 file=("WorldCup2022_ScoreChart_no_macro_20221218.xls")
# ----> 3 a=pd.read_excel(file)
#       4 a
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_xlrd.py:34, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      24 """
#      25 Reader using xlrd engine.
#      26
#    (...)
#      31 {storage_options}
#      32 """
#      33 err_msg = "Install xlrd >= 2.0.1 for xls Excel support"
# ---> 34 import_optional_dependency("xlrd", extra=err_msg)
#      35 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.

# %%
import pandas as pd
file=("WorldCup2022_ScoreChart_no_macro_20221218.xlsx")
a=pd.read_excel(file)
a
# Out:
#    FIFA WORLD CUP 2022 SCORE CHART               Unnamed: 1  Unnamed: 2  \
# 0                              NaN                      NaN  Time Zone:
# 1                                1                      Sun      20-Nov
# 2                                2                      Mon      21-Nov
# 3                               18                      Fri      25-Nov
# 4                               19                      Fri      25-Nov
# ..                             ...                      ...         ...
# 66                             NaN                      NaN         NaN
# 67                             NaN                      NaN         NaN
# 68                             NaN                      NaN         NaN
# 69                             NaN                      NaN         NaN
# 70                    Current Path  D:\Users\Jie\Downloads\         NaN
#
#    Unnamed: 3                     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        Doha                          Venue       City    Country
# 1     7:00 PM                Al Bayt Stadium    Al Khor      Qatar
# 2     7:00 PM             Al Thumama Stadium       Doha      Qatar
# 3     4:00 PM             Al Thumama Stadium       Doha      Qatar
# 4     7:00 PM  Khalifa International Stadium  Al Rayyan      Qatar
# ..        ...                            ...        ...        ...
# 66        NaN                            NaN        NaN        NaN
# 67        NaN                            NaN        NaN        NaN
# 68        NaN                            NaN        NaN        NaN
# 69        NaN                            NaN        NaN        NaN
# 70        NaN                            NaN        NaN        NaN
#
#        Unnamed: 7   Unnamed: 8  Unnamed: 9  ... Unnamed: 61 Unnamed: 62  \
# 0   Group / Stage         Home         NaN  ...         NaN         NaN
# 1         Group A        Qatar         NaN  ...         NaN         NaN
# 2         Group A      Senegal         NaN  ...         NaN         NaN
# 3         Group A        Qatar         NaN  ...         NaN         NaN
# 4         Group A  Netherlands         NaN  ...         NaN         NaN
# ..            ...          ...         ...  ...         ...         ...
# 66            NaN          NaN         NaN  ...         NaN         NaN
# 67            NaN          NaN         NaN  ...         NaN         NaN
# 68            NaN          NaN         NaN  ...         NaN         NaN
# 69            NaN          NaN         NaN  ...         NaN         NaN
# 70            NaN          NaN         NaN  ...         NaN         NaN
#
#    Unnamed: 63 Unnamed: 64 Unnamed: 65 Unnamed: 66 Unnamed: 67  Unnamed: 68  \
# 0          NaN         NaN         NaN       Final         NaN          NaN
# 1          NaN         NaN         NaN         NaN         NaN          NaN
# 2          NaN         NaN         NaN         NaN         NaN          NaN
# 3          NaN         NaN         NaN         NaN         NaN          NaN
# 4          NaN         NaN         NaN      Result         NaN          NaN
# ..         ...         ...         ...         ...         ...          ...
# 66         NaN         NaN         NaN         NaN         NaN          NaN
# 67         NaN         NaN         NaN         NaN         NaN          NaN
# 68         NaN         NaN         NaN         NaN         NaN          NaN
# 69         NaN         NaN         NaN         NaN         NaN          NaN
# 70         NaN         NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 69 Unnamed: 70
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ..         ...         ...
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN
# 69         NaN         NaN
# 70         NaN         NaN
#
# [71 rows x 71 columns]

# %%
# # "ODS" — OpenDocument spreadsheet (.ods)

# %%
import pandas as pd
file=('WorldCup2022_ScoreChart_no_macro_20221218.ods')
a=pd.read_excel(file)
a
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'odf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 3
#       1 import pandas as pd
#       2 file=('WorldCup2022_ScoreChart_no_macro_20221218.ods')
# ----> 3 a=pd.read_excel(file)
#       4 a
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_odfreader.py:44, in ODFReader.__init__(self, filepath_or_buffer, storage_options)
#      30 def __init__(
#      31     self,
#      32     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#      33     storage_options: StorageOptions = None,
#      34 ) -> None:
#      35     """
#      36     Read tables out of OpenDocument formatted files.
#      37
#    (...)
#      42     {storage_options}
#      43     """
# ---> 44     import_optional_dependency("odf")
#      45     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'odfpy'.  Use pip or conda to install odfpy.
